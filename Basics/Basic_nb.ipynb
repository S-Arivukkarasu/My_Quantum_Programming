# %%
import qiskit
qr = qiskit.QuantumRegister(1)
cr = qiskit.ClassicalRegister(1)
program = qiskit.QuantumCircuit(qr, cr)

# %%
program.measure(qr,cr)


job = qiskit.execute( program, qiskit.BasicAer.get_backend('qasm_simulator') )

print( job.result().get_counts() )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 program.measure(qr,cr)
# ----> 4 job = qiskit.execute( program, qiskit.BasicAer.get_backend('qasm_simulator') )
#       6 print( job.result().get_counts() )
#
# AttributeError: module 'qiskit' has no attribute 'execute'

# %%
qiskit.IBMQ.load_accounts()
backend = qiskit.providers.ibmq.least_busy(qiskit.IBMQ.backends(simulator=False))
print("We'll use the least busy device:",backend.name())
job = qiskit.execute( program, backend )
print( job.result().get_counts() )

qp = QuantumProgram()
qr = qp.create_quantum_register('qr',2)
cr = qp.create_classical_register('cr',2)
qc = qp.create_circuit('HelloWorldCircuit', [qr],[cr])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 qiskit.IBMQ.load_accounts()
#       2 backend = qiskit.providers.ibmq.least_busy(qiskit.IBMQ.backends(simulator=False))
#       3 print("We'll use the least busy device:",backend.name())
#
# AttributeError: module 'qiskit' has no attribute 'IBMQ'
